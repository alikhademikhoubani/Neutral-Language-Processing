# %%
# !pip install langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.8/442.8 kB 15.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.66
#     Uninstalling langchain-core-0.3.66:
#       Successfully uninstalled langchain-core-0.3.66
# ...

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 82.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 82.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 90.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 875.5 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 13.7 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq
import chromadb

# %%
llm = ChatGroq(
    temperature = 0,
    groq_api_key = "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",
    model_name = "llama-3.3-70b-versatile"
)

# %%
response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon's surface on July 20, 1969, as part of the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.

# %%
response = llm.invoke("سلام خوبی؟")
print(response.content)
# Out:
# سلام، ممنون. خوبم. شما چطورید؟

# %%
response = llm.invoke("درباره هوش مصنوعی چه می دانی؟")
print(response.content)
# Out:
# هوش مصنوعی (AI) یک رشته علمی است که به طراحی و توسعه سیستم‌های کامپیوتری می‌پردازد که می‌توانند وظایف و کارهای هوشمندی را که معمولاً توسط انسان‌ها انجام می‌شود، انجام دهند. این سیستم‌ها می‌توانند داده‌ها را تجزیه و تحلیل کنند، یاد بگیرند، تصمیم بگیرند و عمل کنند.
#
# هوش مصنوعی شامل چندین زیررشته است، از جمله:
#
# 1. **یادگیری ماشین** (Machine Learning): این زیررشته به توسعه الگوریتم‌ها و مدل‌های آماری می‌پردازد که به سیستم‌ها امکان می‌دهد از داده‌ها یاد بگیرند و پیش‌بینی‌های دقیق‌تری انجام دهند.
# 2. **processing زبان طبیعی** (Natural Language Processing): این زیررشته به توسعه سیستم‌هایی می‌پردازد که می‌توانند زبان طبیعی را درک کنند و با آن تعامل داشته باشند.
# 3. ** بینایی کامپیوتری** (Computer Vision): این زیررشته به توسعه سیستم‌هایی می‌پردازد که می‌توانند تصاویر و ویدیوها را درک کنند و از آنها اطلاعات استخراج کنند.
# 4. **روباتیک** (Robotics): این زیررشته به توسعه سیستم‌هایی می‌پردازد که می‌توانند در محیط‌های فیزیکی عمل کنند و وظایف را به طور خودکار انجام دهند.
#
# ...

# %%
client = chromadb.Client()
collection = client.create_collection(name = "my_collection")

# %%
collection.add(
    documents = [
        "This is about New York",
        "This is about Tehran"
    ],
    ids = ["id1", "id2"]
)
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:01<00:00, 78.4MiB/s]

# %%
all_docs = collection.get()
all_docs
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'documents': ['This is about New York', 'This is about Tehran'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None]}

# %%
documents = collection.get(ids = ["id1"])
documents
# Out:
# {'ids': ['id1'],
#  'embeddings': None,
#  'documents': ['This is about New York'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None]}

# %%
results = collection.query(
    query_texts = ["Query is about Ghorme sabzi"],
    n_results = 2
)
results
# Out:
# {'ids': [['id2', 'id1']],
#  'embeddings': None,
#  'documents': [['This is about Tehran', 'This is about New York']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.4240272045135498, 1.912453293800354]]}

# %%
results = collection.query(
    query_texts = ["Query is about Pizza"],
    n_results = 2
)
results
# Out:
# {'ids': [['id1', 'id2']],
#  'embeddings': None,
#  'documents': [['This is about New York', 'This is about Tehran']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.4515140056610107, 1.5689517259597778]]}

# %%
collection.delete(ids = all_docs['ids'])
collection.get()
# Out:
# {'ids': [],
#  'embeddings': None,
#  'documents': [],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': []}

# %%
collection.add(
    documents = [
        "This document is about New York",
        "This document is about Tehran"
    ],
    ids = ["id3", "id4"],
    metadatas = [
        {"url": "https://en.wikipedia.org/wiki/New_York_City"},
        {"url": "https://en.wikipedia.org/wiki/Tehran"}
    ]
)

# %%
results = collection.query(
    query_texts = ["Query is about Iran"],
    n_results = 2
)
results
# Out:
# {'ids': [['id4', 'id3']],
#  'embeddings': None,
#  'documents': [['This document is about Tehran',
#    'This document is about New York']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'url': 'https://en.wikipedia.org/wiki/Tehran'},
#    {'url': 'https://en.wikipedia.org/wiki/New_York_City'}]],
#  'distances': [[0.5448208451271057, 1.6491315364837646]]}
