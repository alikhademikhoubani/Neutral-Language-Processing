# %%
from typing import TypedDict, Annotated, List, Literal, Dict, Any
from langchain_core.messages import BaseMessage, HumanMessage, AIMessage, SystemMessage
from langgraph.graph import StateGraph, END, MessagesState
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv
import os
import PyPDF2 as pdf
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_core.prompts import PromptTemplate
import requests

# %%
load_dotenv()
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
llm = ChatGroq(model = "llama-3.3-70b-versatile")

# %%
class SupervisorState(MessagesState):
    """State for the multi-agent"""
    next_agent: str = "supervisor"
    flight_data: str = ""
    weather_data: str = ""
    final_report: str = ""
    task_complete: bool = False
    current_task: str = ""

# %%
def create_supervisor_chain():
    """Creates the supervisor decision chain"""
    supervisor_prompt = ChatPromptTemplate.from_messages([
        ("system", """You are a supervisor managing a team of agents:

1. flight - Gathers information about flights between two cities
2. weather - Gathers information about weather of the city
3. Writer - Creates reports and summaries

Based on the current state and conversation, decide which agent should work next.
if the task is complete, respond with 'DONE'.

Current state:
- Has flight data: {has_flight}
- Has weather data: {has_weather}
- Has report: {has_report}

Respond with ONLY the agent name (flight/weather/writer) or 'DONE'.
"""),
        ("human", "{task}")
    ])

    return supervisor_prompt | llm

# %%
def supervisor_agent(state: SupervisorState) -> Dict:
    messages = state.get("messages", [])
    current_task = state.get("current_task", "")

    if not current_task:
        human_msgs = [m for m in messages if isinstance(m, HumanMessage)]
        if human_msgs:
            current_task = human_msgs[-1].content.strip()
        else:
            current_task = "No task"

    has_flight = bool(state.get("flight_data"))
    has_weather = bool(state.get("weather_data"))
    has_report = bool(state.get("final_report"))

    chain = create_supervisor_chain()
    decision = chain.invoke({
        "task": current_task,
        "has_flight": has_flight,
        "has_weather": has_weather,
        "has_report": has_report
    })

    decision_text = decision.content.strip().lower()
    print(f"Supervisor decision: {decision_text}")

    if "done" in decision_text or has_report:
        next_agent = "__end__"
        supervisor_msg = "Supervisor: All tasks complete! Great work team."
    elif "weather" in decision_text or (has_flight and not has_weather):
        next_agent = "weather"
        supervisor_msg = "Supervisor: flight search done. Time for weather search. Assigning to Analyst..."
    elif "writer" in decision_text or (has_weather and not has_report):
        next_agent = "writer"
        supervisor_msg = "Supervisor: weather searching is completed. Let's create the report. Assigning to Writer..."
    else:
        next_agent = "flight"
        supervisor_msg = "Supervisor: Starting with flight. Assigning to flight..."

    return {
        "messages": state["messages"] + [AIMessage(content=supervisor_msg)],
        "next_agent": next_agent,
        "current_task": current_task  
    }

# %%
def flight_agent(state: SupervisorState) -> Dict:
    """Gathers information about flights"""

    api_key = "lNXHKtMRYtRdUiBX6gOnC6IANNmSjdr2"
    api_secret = "0c4xlMMO9wsBpZOm" 

    url = "https://test.api.amadeus.com/v1/security/oauth2/token"

    data = {
        "grant_type": "client_credentials",
        "client_id": api_key,
        "client_secret": api_secret
    }

    response = requests.post(url, data=data)


    access_token = response.json().get("access_token")
 

    origin_city_code = "SYD"  
    destination_city_code = "BKK" 
    departure_date = "2025-11-15" 

    url = f"https://test.api.amadeus.com/v2/shopping/flight-offers"

    params = {
        "originLocationCode": origin_city_code,
        "destinationLocationCode": destination_city_code,
        "departureDate": departure_date,
        "adults": 1, 
        "max": 2 
    }

    headers = {
        "Authorization": f"Bearer {access_token}"
    }

    response = requests.get(url, headers=headers, params=params)

    flights_info = ""

    data = response.json()
    flights = data.get("data", [])
        
    for flight in flights:
        flight_id = flight.get("id")
        price = flight.get("price", {}).get("grandTotal")
        duration = flight.get("itineraries", [{}])[0].get("duration")
            
        flights_info += f"Flight ID: {flight_id}\n"
        flights_info += f"Price: {price} EUR\n"
        flights_info += f"Duration: {duration}\n"
        flights_info += "-" * 24 + "\n"
    
    return {
        "messages": state["messages"] + [AIMessage(content = flights_info)],
        "flight_data": flights_info,
        "next_agent": "supervisor"
    }

# %%
def weather_agent(state: SupervisorState) -> Dict:
    """Gathers information about weather"""
    api_key = "68039a20685c0c855c08ed1f136a33bf" 
    city = "bangkok"
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric&lang=fa"

    response = requests.get(url)
    data = response.json()

    weather_info = ""

    if response.status_code == 200:
        weather_info += f"City: {city}\n"
        weather_info += f"Temperature: {data['main']['temp']}°C\n"
        weather_info += f"Humidity: {data['main']['humidity']}%\n"
        weather_info += f"Weather: {data['weather'][0]['description']}\n"
    else:
        weather_info = "Error fetching data"
    
    return {
        "messages": state["messages"] + [AIMessage(content = weather_info)],
        "weather_data": weather_info,
        "next_agent": "supervisor"
    }

# %%
def writer_agent(state: SupervisorState) -> Dict:
    """Writer uses Groq to create final report"""
    flight_data = state.get("flight_data", "")
    weather_data = state.get("weather_data", "")
    task = state.get("current_task")

    writing_prompt = f"""
You are an expert report writer. Your job is to prepare a report on the cost of airfare and the weather of the destination for a person who is planning to travel, based on the specified task and the flight information and weather information provided, so that the person can find complete information about these matters.

task: {task}

flight data: {flight_data}

weather data: {weather_data}

The length of this report should be 1000 words. 
To separate each section of the report, use separators such as "---". 
Please write a comprehensive report of both flight data and weather data based on the specified task.
"""
    
    report_response = llm.invoke([HumanMessage(content = writing_prompt)])
    report = report_response.content

    final_report = f"""
    final report: 
{'=' * 50}
task: {task}
{'=' * 50}

{report}
"""
    
    return {
        "messages": state["messages"] + [AIMessage(content = "Analyst: I've completed the analysis.\n\nTop insights:\n{report}...")],
        "final_report": final_report,
        "next_agent": "supervisor",
        "task_complete": True
    }

# %%
def router(state: SupervisorState):
    next_agent = state.get("next_agent", "supervisor")
    
    if next_agent in ["__end__", "end"] or state.get("task_complete", False):
        return END
    
    if next_agent in ["supervisor", "flight", "weather", "writer"]:
        return next_agent
    
    return "supervisor"

# %%
workflow = StateGraph(SupervisorState)

workflow.add_node("supervisor", supervisor_agent)
workflow.add_node("flight", flight_agent)
workflow.add_node("weather", weather_agent)
workflow.add_node("writer", writer_agent)

workflow.set_entry_point("supervisor")

for node in ["supervisor", "flight", "weather", "writer"]:
    workflow.add_conditional_edges(
        node,
        router,
        {
            "supervisor": "supervisor",
            "flight": "flight",
            "weather": "weather",
            "writer": "writer",
            "__end__": END
        }
    )

graph = workflow.compile()

# %%
response = graph.invoke({
    "messages": [HumanMessage(content="I want to fly from Sydney (SYD) to Bangkok (BKK). How much does it cost to fly and what is the weather like there right now?")]
})
# Out:
# Supervisor decision: flight
# Supervisor decision: weather
# Supervisor decision: flight

# %%
response
# Out:
# {'messages': [HumanMessage(content='I want to fly from Sydney (SYD) to Bangkok (BKK). How much does it cost to fly and what is the weather like there right now?', additional_kwargs={}, response_metadata={}, id='ab89b021-4ba0-4906-b360-ed1bb23fa6ea'),
#   AIMessage(content='Supervisor: Starting with flight. Assigning to flight...', additional_kwargs={}, response_metadata={}, id='9cf4a174-2b93-45bd-ba61-85beb45f4adb'),
#   AIMessage(content='Flight ID: 1\nPrice: 204.40 EUR\nDuration: PT14H30M\n------------------------\nFlight ID: 2\nPrice: 215.68 EUR\nDuration: PT16H15M\n------------------------\n', additional_kwargs={}, response_metadata={}, id='35f3dcdc-e696-46ad-afd4-d26e583edd91'),
#   AIMessage(content='Supervisor: flight search done. Time for weather search. Assigning to Analyst...', additional_kwargs={}, response_metadata={}, id='30f88776-55fe-421c-b414-d456e4a653bf'),
#   AIMessage(content='City: bangkok\nTemperature: 27.06°C\nHumidity: 77%\nWeather: پوشیده از ابر\n', additional_kwargs={}, response_metadata={}, id='5b80839a-fcb5-4d1b-a031-b77677916c30'),
#   AIMessage(content="Supervisor: weather searching is completed. Let's create the report. Assigning to Writer...", additional_kwargs={}, response_metadata={}, id='cb0c0439-0a81-476d-b790-ea725c392b0b'),
#   AIMessage(content="Analyst: I've completed the analysis.\n\nTop insights:\n{report}...", additional_kwargs={}, response_metadata={}, id='831d7464-e1df-468f-b92a-21fb7ea000de')],
#  'next_agent': 'supervisor',
#  'flight_data': 'Flight ID: 1\nPrice: 204.40 EUR\nDuration: PT14H30M\n------------------------\nFlight ID: 2\nPrice: 215.68 EUR\nDuration: PT16H15M\n------------------------\n',
#  'weather_data': 'City: bangkok\nTemperature: 27.06°C\nHumidity: 77%\nWeather: پوشیده از ابر\n',
#  'final_report': '\n    final report: \n==================================================\ntask: I want to fly from Sydney (SYD) to Bangkok (BKK). How much does it cost to fly and what is the weather like there right now?\n==================================================\n\n**Introduction**\nThe purpose of this report is to provide a comprehensive overview of the cost of airfare and the current weather conditions in Bangkok, Thailand, for a traveler planning to fly from Sydney, Australia. The report will analyze the available flight data and weather information to help the traveler make an informed decision about their trip.\n\n---\n**Flight Information**\nThe flight data provided includes two options for flying from Sydney (SYD) to Bangkok (BKK). The details of each flight are as follows:\n\n* Flight ID: 1\n\t+ Price: 204.40 EUR\n\t+ Duration: 14 hours and 30 minutes (PT14H30M)\n* Flight ID: 2\n\t+ Price: 215.68 EUR\n\t+ Duration: 16 hours and 15 minutes (PT16H15M)\n\nAs can be seen from the data, the prices of the two flights are relatively close, with a difference of approximately 11.28 EUR. However, the duration of the flights varies significantly, with Flight ID: 1 being 1 hour and 45 minutes shorter than Flight ID: 2. This difference in duration may be an important consideration for travelers who value their time or have connecting flights to catch.\n\nIn terms of cost, both flights are relatively affordable, with prices under 220 EUR. However, it is essential to note that these prices may not include additional fees for services such as checked baggage, meals, or seat selection. Travelers should factor in these potential extra costs when comparing the prices of the two flights.\n\n---\n**Weather Conditions in Bangkok**\nThe current weather conditions in Bangkok, Thailand, are as follows:\n\n* City: Bangkok\n* Temperature: 27.06°C\n* Humidity: 77%\n* Weather: پوشیده از ابر (Cloudy)\n\nThe temperature in Bangkok is currently 27.06°C, which is relatively warm and humid. The humidity level is 77%, which is quite high, indicating a tropical climate. The weather is cloudy, which may be a welcome relief from the sun for some travelers.\n\nIt is essential to note that the weather in Bangkok can be quite unpredictable, and conditions can change rapidly. Travelers should be prepared for sudden rain showers or intense sunlight, even on cloudy days. The warm and humid climate also means that travelers should take necessary precautions to stay hydrated and protect themselves from the sun.\n\n---\n**Comparison of Flight Options and Weather Conditions**\nWhen considering the flight options and weather conditions, travelers should weigh the pros and cons of each. Flight ID: 1 offers a shorter duration and a slightly lower price, but travelers should consider whether the 1 hour and 45 minutes saved is worth the potential trade-offs in terms of other factors such as layovers, airline amenities, and flight schedules.\n\nOn the other hand, Flight ID: 2 offers a longer duration, but may provide more flexibility in terms of flight schedules or layovers. Travelers should also consider the potential impact of the weather conditions on their travel plans. The cloudy and humid weather in Bangkok may require travelers to pack accordingly, with lightweight and breathable clothing, sunscreen, and rain gear.\n\n---\n**Recommendations for Travelers**\nBased on the analysis of the flight data and weather information, the following recommendations are made for travelers:\n\n* Book Flight ID: 1 for a shorter duration and slightly lower price, but be aware of potential trade-offs in terms of other factors.\n* Pack accordingly for the warm and humid climate in Bangkok, with lightweight and breathable clothing, sunscreen, and rain gear.\n* Stay hydrated and take necessary precautions to protect yourself from the sun, even on cloudy days.\n* Consider purchasing travel insurance to cover unexpected changes in flight schedules or weather conditions.\n* Res ...
#  'task_complete': True,
#  'current_task': 'I want to fly from Sydney (SYD) to Bangkok (BKK). How much does it cost to fly and what is the weather like there right now?'}

# %%
flight_output = response['messages'][2].content
weather_output = response['messages'][4].content
writer_output = response['messages'][6].content
final_report = response['final_report']

print("Researcher Output:\n", flight_output)
print("Summarizer Output:\n", weather_output)
print("Writer Output:\n", writer_output)
print(final_report)
# Out:
# Researcher Output:
#  Flight ID: 1
# Price: 204.40 EUR
# Duration: PT14H30M
# ------------------------
# Flight ID: 2
# Price: 215.68 EUR
# Duration: PT16H15M
# ------------------------
#
# Summarizer Output:
#  City: bangkok
# Temperature: 27.06°C
# Humidity: 77%
# Weather: پوشیده از ابر
#
# Writer Output:
#  Analyst: I've completed the analysis.
#
# Top insights:
# {report}...
#
#     final report:
# ==================================================
# task: I want to fly from Sydney (SYD) to Bangkok (BKK). How much does it cost to fly and what is the weather like there right now?
# ==================================================
#
# **Introduction**
# The purpose of this report is to provide a comprehensive overview of the cost of airfare and the current weather conditions in Bangkok, Thailand, for a traveler planning to fly from Sydney, Australia. The report will analyze the available flight data and weather information to help the traveler make an informed decision about their trip.
#
# ---
# **Flight Information**
# The flight data provided includes two options for flying from Sydney (SYD) to Bangkok (BKK). The details of each flight are as follows:
#
# * Flight ID: 1
# 	+ Price: 204.40 EUR
# 	+ Duration: 14 hours and 30 minutes (PT14H30M)
# * Flight ID: 2
# 	+ Price: 215.68 EUR
# 	+ Duration: 16 hours and 15 minutes (PT16H15M)
#
# As can be seen from the data, the prices of the two flights are relatively close, with a difference of approximately 11.28 EUR. However, the duration of the flights varies significantly, with Flight ID: 1 being 1 hour and 45 minutes shorter than Flight ID: 2. This difference in duration may be an important consideration for travelers who value their time or have connecting flights to catch.
#
# In terms of cost, both flights are relatively affordable, with prices under 220 EUR. However, it is essential to note that these prices may not include additional fees for services such as checked baggage, meals, or seat selection. Travelers should factor in these potential extra costs when comparing the prices of the two flights.
#
# ---
# **Weather Conditions in Bangkok**
# The current weather conditions in Bangkok, Thailand, are as follows:
#
# * City: Bangkok
# * Temperature: 27.06°C
# * Humidity: 77%
# * Weather: پوشیده از ابر (Cloudy)
#
# The temperature in Bangkok is currently 27.06°C, which is relatively warm and humid. The humidity level is 77%, which is quite high, indicating a tropical climate. The weather is cloudy, which may be a welcome relief from the sun for some travelers.
#
# It is essential to note that the weather in Bangkok can be quite unpredictable, and conditions can change rapidly. Travelers should be prepared for sudden rain showers or intense sunlight, even on cloudy days. The warm and humid climate also means that travelers should take necessary precautions to stay hydrated and protect themselves from the sun.
#
# ---
# **Comparison of Flight Options and Weather Conditions**
# When considering the flight options and weather conditions, travelers should weigh the pros and cons of each. Flight ID: 1 offers a shorter duration and a slightly lower price, but travelers should consider whether the 1 hour and 45 minutes saved is worth the potential trade-offs in terms of other factors such as layovers, airline amenities, and flight schedules.
#
# On the other hand, Flight ID: 2 offers a longer duration, but may provide more flexibility in terms of flight schedules or layovers. Travelers should also consider the potential impact of the weather conditions on their travel plans. The cloudy and humid weather in Bangkok may require travelers to pack accordingly, with lightweight and breathable clothing, sunscreen, and rain gear.
#
# ---
# **Recommendations for Travelers**
# Based on the analysis of the flight data and weather information, the following recommendations are made for travelers:
#
# * Book Flight ID: 1 for a shorter duration and slightly lower price, but be aware of potential trade-offs in terms of other factors.
# * Pack accordingly for the warm and humid climate in Bangkok, with lightweight and breathable clothing, sunscreen, and rain gear.
# * Stay hydrated and take necessary precautions to protect yourself from the sun, even on cloudy days.
# * Consider purchasing travel insurance to cover unexpected changes in flight schedules or weather conditions.
# * Research and book accommodations and activities in Bangkok that are suitable for the weather conditions and your personal preferences.
#
# ---
# **Conclusion**
# In conclusion, this report provides a comprehensive overview of the cost of airfare and the current weather conditions in Bangkok, Thailand, for a traveler planning to fly from Sydney, Australia. The analysis of the flight data and weather information highlights the importance of considering multiple factors when making travel decisions. By weighing the pros and cons of each flight option and preparing for the weather conditions, travelers can make informed decisions and have a more enjoyable and stress-free trip.
#
# ---
# **Additional Information**
# To further assist travelers, the following additional information is provided:
#
# * The best time to visit Bangkok is from November to February, when the weather is cooler and drier.
# * The peak tourist season in Bangkok is from June to August, when the weather is hot and humid.
# * Travelers should be aware of the potential for rain showers and flooding in Bangkok during the monsoon season, which typically runs from May to October.
# * The city has a comprehensive public transportation system, including buses, trains, and taxis, making it easy to get around without a car.
# * Bangkok is a popular destination for foodies, with a wide range of street food, restaurants, and night markets to explore.
#
# ---
# **Appendix**
# The following tables and figures provide additional information and context for the report:
#
# Table 1: Flight Data Comparison
#
# | Flight ID | Price (EUR) | Duration |
# | --- | --- | --- |
# | 1 | 204.40 | 14h 30m |
# | 2 | 215.68 | 16h 15m |
#
# Figure 1: Bangkok Weather Forecast
#
# (Note: The figure is not included in this text-based report, but would typically be a graphical representation of the weather forecast for Bangkok)
#
# By considering the information provided in this report, travelers can make informed decisions about their trip and have a more enjoyable and stress-free experience in Bangkok.
#
# ---
# **References**
# The data used in this report was provided by external sources, including flight databases and weather APIs. The accuracy and reliability of the data are dependent on these sources, and travelers should always verify the information with multiple sources before making travel decisions.
#
# In terms of weather forecasting, the data used in this report is subject to change and may not reflect the current weather conditions at the time of travel. Travelers should always check the latest weather forecast before departing and during their trip to stay informed and prepared.
#
# The report is based on the specified task and the flight information and weather information provided, and is intended to provide a comprehensive overview of the cost of airfare and the weather conditions in Bangkok, Thailand. The length of the report is approximately 1000 words, and includes separators such as --- to separate each section of the report.
#
# The report includes an introduction, flight information, weather conditions, comparison of flight options and weather conditions, recommendations for travelers, conclusion, additional information, appendix, and references. The report is written in a clear and concise manner, and includes tables and figures to provide additional information and context.
#
# Overall, the report provides a comprehensive overview of the cost of airfare and the weather conditions in Bangkok, Thailand, and is intended to assist travelers in making informed decisions about their trip.
