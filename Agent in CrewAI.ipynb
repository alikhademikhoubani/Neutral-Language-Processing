# %%
from dotenv import load_dotenv
from crewai import LLM, Agent, Task, Crew
load_dotenv()
# Out:
# True

# %%
llm = LLM(model="groq/llama-3.3-70b-versatile")

# %%
llm.call("Who invented transcendental meditation")
# Out:
# 'Transcendental Meditation (TM) was developed by Maharishi Mahesh Yogi, an Indian guru and spiritual leader. Maharishi Mahesh Yogi (1918-2008) was born Mahesh Prasad Varma in Jabalpur, India, and studied physics at the University of Allahabad. He later became a disciple of Swami Brahmananda Saraswati, also known as Guru Dev, who was the Shankaracharya of Jyotir Math, a prestigious Hindu monastery in India.\n\nAfter Guru Dev\'s death in 1953, Maharishi Mahesh Yogi began to develop and teach his own meditation technique, which he called Transcendental Meditation. He claimed that TM was a simplified and standardized version of an ancient Vedic meditation technique that had been passed down through the Shankaracharya tradition.\n\nMaharishi Mahesh Yogi introduced TM to the Western world in the 1950s and 1960s, and it quickly gained popularity, particularly among the counterculture movement of the 1960s. The Beatles, who visited Maharishi Mahesh Yogi in India in 1968, were among his most famous students.\n\nTM involves the use of a mantra, or a word or sound that is repeated silently to help the mind settle into a deeper state of consciousness. The goal of TM is to experience a state of "pure consciousness," or a state of awareness that is beyond thought and mental activity. Maharishi Mahesh Yogi claimed that regular practice of TM could lead to a range of benefits, including reduced stress, improved mental clarity, and increased feelings of happiness and well-being.'

# %%
email_assistant = Agent(
    role = "Email Assistant Agent",
    goal = "Improve emails and make them sound professional and clear",
    backstory = "A highly experienced communication expert skilled in professional email writting",
    verbose = True,
    llm = llm
)

# %%
original_email = """
hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.
Maybe we can show what we have and say rest is WIP.
Let me know what u think. thanks
"""

# %%
email_task = Task(
    description = f"""Take the following rough email and rewrite it into a professional and polished
     version.
    Expand abbreviations:
    '''{original_email}''''""",
    agent = email_assistant,
    expected_output = "A professional written email with proper formatting and content."
)

# %%
crew = Crew(
    agents = [email_assistant],
    tasks = [email_task],
    verbose = True
)

# %%
result = crew.kickoff()
print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 0dac8bd6-911b-4e8d-be70-f63d3ba9bbbe                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Email Assistant Agent                                                                                   │
# │                                                                                                                 │
# │  Task: Take the following rough email and rewrite it into a professional and polished                           │
# │       version.                                                                                                  │
# │      Expand abbreviations:                                                                                      │
# │      '''                                                                                                        │
# │  hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.                  │
# │  Maybe we can show what we have and say rest is WIP.                                                            │
# │  Let me know what u think. thanks                                                                               │
# │  ''''                                                                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Email Assistant Agent                                                                                   │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Subject: Update on Demo Preparation                                                                            │
# │                                                                                                                 │
# │  Dear Team,                                                                                                     │
# │                                                                                                                 │
# │  I wanted to touch base with you regarding the current status of the demo. While we have made significant       │
# │  progress, there are still some outstanding tasks that need to be completed. Despite this, I believe we have a  │
# │  solid foundation to work with and can potentially showcase what we have achieved so far.                       │
# │                                                                                                                 │
# │  One possible approach could be to present the demo as it stands, while clearly indicating which components     │
# │  are still a work in progress (WIP). This would allow us to share our progress with the relevant stakeholders,  │
# │  while also managing their expectations and providing a realistic timeline for completion.                      │
# │                                                                                                                 │
# │  I would appreciate your feedback on this proposal and welcome any suggestions you may have. Please let me      │
# │  know your thoughts on how to proceed, and thank you for your ongoing support and collaboration.                │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │  [Your Name]                                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 26caee40-eace-4cd8-ab2b-356e759fd7ba                                                                     │
# │  Agent: Email Assistant Agent                                                                                   │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
