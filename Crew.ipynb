# %%
from dotenv import load_dotenv
from crewai import LLM, Agent, Task, Crew
load_dotenv()
# Out:
# True

# %%
llm = LLM(model="groq/llama-3.3-70b-versatile")

# %%
research_agent = Agent(
    role = "Researcher Specialist",
    goal = "Research interesting facts about the topic: {topic}",
    backstory = "You are an expert at finding relevant and factual data.",
    verbose = True,
    llm = llm
)

# %%
writer_agent = Agent(
    role = "Creative Writer",
    goal = "Write a short blog summary using the research",
    backstory = "You are skilled at writting engaging summaries based on provided content.",
    llm = llm,
    verbose = True
)

# %%
task1 = Task(
    description = "Find 3-5 interesting and recent facts about {topic}.",
    expected_output = "A bullet list of 3-5 facts",
    agent = research_agent
)

# %%
task2 = Task(
    description = "Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output = "A blog post summary",
    agent = writer_agent,
    context = [task1]
)

# %%
crew = Crew(
    agents = [research_agent, writer_agent],
    tasks = [task1, task2],
    verbose = True
)

# %%
result = crew.kickoff(inputs = {"topic": "The future of electronical vehicles"})
print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 2698fb03-6e52-4bd8-a5a7-8c114e45475f                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Researcher Specialist                                                                                   │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electronical vehicles.                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Researcher Specialist                                                                                   │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  * By 2030, it's estimated that over 50% of new car sales will be electric vehicles (EVs), with many countries  │
# │  investing heavily in EV infrastructure and incentivizing their adoption to reduce greenhouse gas emissions     │
# │  and improve air quality.                                                                                       │
# │  * Solid-state batteries are expected to revolutionize the EV industry, offering faster charging times,         │
# │  increased range, and improved safety compared to traditional lithium-ion batteries, with several companies     │
# │  already working on commercializing this technology.                                                            │
# │  * The future of EVs is also closely tied to the development of autonomous vehicles, with many manufacturers    │
# │  exploring the potential for self-driving EVs to transform the way we think about transportation, from          │
# │  ride-sharing and public transit to personal ownership and vehicle subscription services.                       │
# │  * Wireless charging is another area of innovation in the EV space, with companies like WiTricity and Momentum  │
# │  Dynamics working on technology that would allow EVs to charge without being physically plugged in, making it   │
# │  easier to own and operate an EV, especially for those with limited parking or charging infrastructure.         │
# │  * Governments around the world are implementing policies to encourage the adoption of EVs, such as tax         │
# │  credits, rebates, and investments in EV charging infrastructure, with the goal of reducing dependence on       │
# │  fossil fuels and mitigating the impacts of climate change, and it's expected that these efforts will continue  │
# │  to drive growth in the EV market in the coming years.                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: a6be870c-bac0-4f55-865d-287513d444db                                                                     │
# │  Agent: Researcher Specialist                                                                                   │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The Future of Electric Vehicles: A Revolutionary Road Ahead                                                    │
# │                                                                                                                 │
# │  As the world shifts towards a more sustainable future, electric vehicles (EVs) are taking center stage. By     │
# │  2030, it's estimated that over 50% of new car sales will be EVs, with many countries investing heavily in EV   │
# │  infrastructure and incentivizing their adoption to reduce greenhouse gas emissions and improve air quality.    │
# │  Solid-state batteries are expected to revolutionize the EV industry, offering faster charging times,           │
# │  increased range, and improved safety compared to traditional lithium-ion batteries. The future of EVs is also  │
# │  closely tied to the development of autonomous vehicles, with many manufacturers exploring the potential for    │
# │  self-driving EVs to transform the way we think about transportation. Additionally, wireless charging           │
# │  technology is being developed to make owning and operating an EV even easier, especially for those with        │
# │  limited parking or charging infrastructure. With governments around the world implementing policies to         │
# │  encourage the adoption of EVs, such as tax credits, rebates, and investments in EV charging infrastructure,    │
# │  the future of electric vehicles looks brighter than ever. As technology continues to advance and policies      │
# │  continue to support the growth of the EV market, it's expected that electric vehicles will play a major role   │
# │  in reducing our dependence on fossil fuels and mitigating the impacts of climate change.                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 2698fb03-6e52-4bd8-a5a7-8c114e45475f                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: The Future of Electric Vehicles: A Revolutionary Road Ahead                                      │
# │                                                                                                                 │
# │  As the world shifts towards a more sustainable future, electric vehicles (EVs) are taking center stage. By     │
# │  2030, it's estimated that over 50% of new car sales will be EVs, with many countries investing heavily in EV   │
# │  infrastructure and incentivizing their adoption to reduce greenhouse gas emissions and improve air quality.    │
# │  Solid-state batteries are expected to revolutionize the EV industry, offering faster charging times,           │
# │  increased range, and improved safety compared to traditional lithium-ion batteries. The future of EVs is also  │
# │  closely tied to the development of autonomous vehicles, with many manufacturers exploring the potential for    │
# │  self-driving EVs to transform the way we think about transportation. Additionally, wireless charging           │
# │  technology is being developed to make owning and operating an EV even easier, especially for those with        │
# │  limited parking or charging infrastructure. With governments around the world implementing policies to         │
# │  encourage the adoption of EVs, such as tax credits, rebates, and investments in EV charging infrastructure,    │
# │  the future of electric vehicles looks brighter than ever. As technology continues to advance and policies      │
# │  continue to support the growth of the EV market, it's expected that electric vehicles will play a major role   │
# │  in reducing our dependence on fossil fuels and mitigating the impacts of climate change.                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 8015143f-deb7-4ece-ab32-eede0658ea9f                                                                     │
# │  Agent: Creative Writer                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
