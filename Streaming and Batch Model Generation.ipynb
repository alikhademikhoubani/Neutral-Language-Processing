# %%
from dotenv import load_dotenv 
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

# %%
model = init_chat_model("groq:llama-3.3-70b-versatile")

# %%
model.invoke("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content='Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. AI systems use algorithms and data to make predictions, classify objects, and generate insights, often with a high degree of accuracy and speed. The field of AI has made tremendous progress in recent years, with applications in areas such as natural language processing, computer vision, and robotics. AI-powered systems are being used in a variety of industries, including healthcare, finance, and transportation, to improve efficiency, productivity, and customer experience. For example, virtual assistants like Siri and Alexa use AI to understand voice commands and respond accordingly, while self-driving cars use AI to navigate roads and avoid obstacles. Additionally, AI-powered chatbots are being used in customer service to provide personalized support and answer frequently asked questions. As AI technology continues to evolve, we can expect to see even more innovative applications in the future, transforming the way we live and work. With its potential to automate routine tasks and augment human capabilities, AI is poised to have a significant impact on various aspects of our lives.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 229, 'prompt_tokens': 45, 'total_tokens': 274, 'completion_time': 0.531384408, 'prompt_time': 0.001199192, 'queue_time': 0.047623316, 'total_time': 0.5325836}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b831a-ad8a-74a2-b66d-144a1533fbce-0', usage_metadata={'input_tokens': 45, 'output_tokens': 229, 'total_tokens': 274})

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end = "")
# Out:
# Artificial Intelligence (AI) has revolutionized the way we live, work, and interact with technology. AI refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. From virtual assistants like Siri and Alexa to self-driving cars and personalized product recommendations, AI is ubiquitous in modern life. AI algorithms can analyze vast amounts of data, identify patterns, and make predictions, enabling applications like image recognition, natural language processing, and predictive maintenance. The potential of AI is vast, with applications in healthcare, finance, education, and transportation, among others. As AI continues to evolve, we can expect to see significant advancements in areas like machine learning, deep learning, and cognitive computing. With the ability to automate routine tasks, enhance customer experiences, and drive business innovation, AI is poised to transform industries and create new opportunities for growth and development. However, as AI becomes more pervasive, it also raises important questions about ethics, bias, and job displacement, highlighting the need for responsible AI development and deployment.

# %%
for chunk in model.stream("Why do parrots have colorful feathers"):
    print(chunk.text, end = "", flush = True)
# Out:
# Parrots have colorful feathers for several reasons, which can be broadly categorized into communication, camouflage, and attraction. Here are some possible explanations:
#
# 1. **Communication and Social Signaling**: Parrots use their bright plumage to communicate with other parrots, conveying information about their species, sex, age, health, and social status. Different colors and patterns can signal dominance, courtship, or warning signals to potential competitors.
# 2. **Mating and Attraction**: Vibrant feathers play a crucial role in attracting mates. Bright colors can indicate a parrot's genetic quality, health, and fertility, making them more attractive to potential partners. In some species, males will engage in elaborate courtship displays, showing off their colorful feathers to impress females.
# 3. **Camouflage and Defense**: While it may seem counterintuitive, some parrots' bright colors can actually serve as camouflage in their natural environments. For example, the bright greens and blues of some parrot species can help them blend in with the foliage of their rainforest habitats. Additionally, bright colors can also serve as a warning to potential predators, signaling that the parrot is toxic or distasteful.
# 4. **Thermoregulation**: Some researchers suggest that the bright colors of parrots may help regulate their body temperature. The dark colors can absorb heat, while the light colors can reflect it, helping the parrot to maintain a stable body temperature in varying climates.
# 5. **Evolutionary Adaptation**: The evolution of colorful feathers in parrots may have been driven by a combination of these factors. Over time, natural selection favored individuals with brighter, more vibrant plumage, as these traits conferred advantages in terms of survival, mating, and social interactions.
#
# Some interesting facts about parrot feathers:
#
# * Parrots have a unique feather structure, with microscopic, plate-like scales that reflect light and create their vibrant colors.
# * The bright colors of parrots are not just limited to their feathers; many species also have brightly colored beaks, legs, and facial skin.
# * Parrots can control the color intensity of their feathers by adjusting the angle of the microscopic scales, allowing them to change the appearance of their plumage.
#
# Overall, the colorful feathers of parrots have evolved to serve multiple purposes, from communication and attraction to camouflage and thermoregulation.

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers for several reasons, including:\n\n1. **Communication and Expression**: Colorful feathers help parrots communicate with each other, express their emotions, and signal their intentions. Different colors can convey different messages, such as aggression, courtship, or warning calls.\n2. **Mating and Attraction**: Bright, vibrant feathers can be an attractive feature for potential mates. Parrots with more intense or unique coloration may be more desirable to mates, which can lead to better reproductive success.\n3. **Camouflage and Defense**: While it may seem counterintuitive, some parrots' bright colors can actually serve as camouflage in their natural habitats. For example, a parrot with green feathers may blend in with the foliage of a rainforest. Additionally, bright colors can be used to distract or intimidate predators.\n4. **Social Status**: In some parrot species, coloration can indicate social status or dominance. For example, a parrot with brighter or more vibrant feathers may be higher in the social hierarchy.\n5. **Evolutionary Adaptation**: The evolution of colorful feathers in parrots may have been driven by the need to adapt to their environment. For example, some parrots have evolved to have bright colors that reflect the colors of their food sources, such as fruits or flowers.\n6. **Visual Display**: Parrots use their colorful feathers to create visual displays, such as courtship displays or threat displays. These displays can involve spreading their wings, fanning their tails, or performing other elaborate behaviors.\n7. **Ultraviolet (UV) Reflectance**: Many parrots have feathers that reflect UV light, which is invisible to humans. This UV reflectance can be an important factor in communication and mate choice, as some birds can see into the UV spectrum.\n\nOverall, the colorful feathers of parrots serve multiple purposes and have evolved to play a crucial role in their behavior, ecology, and evolution." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 392, 'prompt_tokens': 43, 'total_tokens': 435, 'completion_time': 1.193210203, 'prompt_time': 0.001560658, 'queue_time': 0.047567435, 'total_time': 1.194770861}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019b8324-a714-7893-860d-56321de0b01f-0' usage_metadata={'input_tokens': 43, 'output_tokens': 392, 'total_tokens': 435}
# content="Airplanes fly by using a combination of four main forces: lift, weight, thrust, and drag. Here's a simplified explanation of how these forces work together to make an airplane take to the skies:\n\n1. **Lift**: Lift is the upward force that opposes the weight of the airplane and keeps it flying. It's created by the wings, which are designed to produce a difference in air pressure above and below the wing. As the airplane moves forward, the air flows over and under the curved surface of the wing, creating an area of lower pressure above the wing and an area of higher pressure below it. This pressure difference creates an upward force, or lift, that counteracts the weight of the airplane.\n2. **Weight**: Weight is the downward force that pulls the airplane towards the ground. It's the combined weight of the airplane itself, the passengers, cargo, and fuel.\n3. **Thrust**: Thrust is the forward force that propels the airplane through the air. It's created by the airplane's engines, which produce a stream of high-speed air that exits the back of the plane. As this air exits, it produces a reaction force that pushes the airplane forward, counteracting the drag.\n4. **Drag**: Drag is the backward force that opposes the motion of the airplane. It's created by air resistance, which slows down the airplane as it moves through the air. Drag is affected by the shape of the airplane, its speed, and the density of the air.\n\nWhen an airplane is in flight, these four forces are in balance:\n\n* Lift equals weight, keeping the airplane at a steady altitude.\n* Thrust equals drag, keeping the airplane moving at a steady speed.\n\nTo generate lift, airplanes use a combination of wing shape, angle of attack, and airspeed. The wing is curved on top and flat on the bottom, which creates a longer path for the air to follow over the top of the wing. As the air flows over the curved surface, it accelerates and its pressure decreases. This creates a region of lower pressure above the wing and a region of higher pressure below it, resulting in an upward force called lift.\n\nAirplanes also use control surfaces, such as ailerons, elevators, and rudder, to control the direction of the lift and thrust forces. By adjusting the angle of attack of the wing and the orientation of the control surfaces, the pilot can control the airplane's roll, pitch, and yaw, allowing it to climb, descend, turn, and maintain a steady course.\n\nIn summary, airplanes fly by using the shape of the wing to create lift, the engines to produce thrust, and the control surfaces to control the direction of the forces. The balance of these four forces – lift, weight, thrust, and drag – allows the airplane to take to the skies and stay aloft." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 580, 'prompt_tokens': 40, 'total_tokens': 620, 'completion_time': 1.232115853, 'prompt_time': 0.001198693, 'queue_time': 0.048062143, 'total_time': 1.233314546}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019b8324-a717-7b02-8700-dafbf62a0647-0' usage_metadata={'input_tokens': 40, 'output_tokens': 580, 'total_tokens': 620}
# content='Quantum computing is a new and rapidly developing field of computer science that uses the principles of quantum mechanics to perform calculations and operations on data. Unlike classical computers, which use bits to store and process information, quantum computers use quantum bits or qubits.\n\n**Classical vs. Quantum Computing:**\n\nClassical computers use bits, which can have a value of either 0 or 1. These bits are used to perform calculations and operations, such as addition and multiplication, using logical gates. However, as the number of bits increases, the complexity of the calculations and the amount of data that needs to be processed also increases, making it difficult for classical computers to solve certain problems efficiently.\n\nQuantum computers, on the other hand, use qubits, which can exist in multiple states simultaneously, known as a superposition. This means that a qubit can represent not just 0 or 1, but also any linear combination of 0 and 1, such as 0.5 or 0.75. Additionally, qubits can become "entangled," meaning that the state of one qubit is dependent on the state of another qubit, even if they are separated by large distances.\n\n**Key Features of Quantum Computing:**\n\n1. **Superposition**: Qubits can exist in multiple states simultaneously, allowing for the exploration of an exponentially large solution space.\n2. **Entanglement**: Qubits can become entangled, enabling the creation of a shared quantum state between multiple qubits.\n3. **Quantum parallelism**: Quantum computers can perform many calculations simultaneously, thanks to the principles of superposition and entanglement.\n4. **Quantum interference**: Quantum computers can exploit the interference between different quantum states to cancel out incorrect solutions and amplify correct ones.\n\n**Applications of Quantum Computing:**\n\n1. **Cryptography**: Quantum computers can potentially break certain classical encryption algorithms, but they can also be used to create new, quantum-resistant encryption methods.\n2. **Optimization**: Quantum computers can be used to solve complex optimization problems, such as finding the shortest path in a network or the most efficient schedule for a set of tasks.\n3. **Simulation**: Quantum computers can simulate complex quantum systems, allowing for the study of materials science, chemistry, and other fields.\n4. **Machine Learning**: Quantum computers can be used to speed up certain machine learning algorithms, such as k-means clustering and support vector machines.\n\n**Challenges and Limitations:**\n\n1. **Quantum noise**: Quantum computers are prone to errors due to the noisy nature of quantum systems.\n2. **Scalability**: Currently, most quantum computers are small-scale and can only perform a limited number of calculations.\n3. **Quantum control**: Maintaining control over the quantum states of qubits is essential for reliable quantum computing.\n4. **Standards and interoperability**: The development of standards and protocols for quantum computing is still in its early stages.\n\nQuantum computing has the potential to revolutionize many fields, from materials science to finance, by solving complex problems that are currently intractable or require an unfeasible amount of time to solve using classical computers. However, significant technical challenges need to be overcome before quantum computing can become a practical reality.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 655, 'prompt_tokens': 40, 'total_tokens': 695, 'completion_time': 1.355395088, 'prompt_time': 0.001691596, 'queue_time': 0.048169979, 'total_time': 1.357086684}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019b8324-a71a-7b40-aaf9-4af72c24138f-0' usage_metadata={'input_tokens': 40, 'output_tokens': 655, 'total_tokens': 695}

# %%
model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
], config = {"max_concurrency": 5})
# Out:
# [AIMessage(content="Parrots have colorful feathers for several reasons:\n\n1. **Communication and Expression**: Bright colors help parrots communicate with each other, express their emotions, and establish social bonds. They use their vibrant feathers to signal aggression, courtship, or friendliness.\n2. **Mating and Attraction**: Colorful feathers play a crucial role in attracting mates. Many parrot species have distinctive color patterns that help them recognize potential partners. The brighter and more vibrant the feathers, the more attractive the parrot may be to a potential mate.\n3. **Camouflage and Defense**: While it may seem counterintuitive, some parrots' bright colors can actually serve as camouflage in their natural environments. For example, the brilliant blues and greens of some parrot species can help them blend in with the foliage of their rainforest habitats.\n4. **Intimidation and Warning**: Bright colors can also serve as a warning to potential predators. Some parrots have bold, eye-catching colors that signal to predators that they are toxic, distasteful, or otherwise unpalatable.\n5. **Thermoregulation**: Some research suggests that the bright colors of parrots' feathers may help regulate their body temperature. The darker colors can absorb heat, while the lighter colors can reflect it, helping the parrot maintain a stable body temperature.\n6. **Evolutionary Advantage**: The evolution of colorful feathers in parrots may have been driven by the need to stand out in their environment. In a crowded, competitive ecosystem, bright colors can give a parrot an edge in terms of finding food, attracting mates, or defending its territory.\n\nOverall, the colorful feathers of parrots serve multiple purposes, including communication, mating, defense, and thermoregulation. These vibrant feathers are an essential part of a parrot's biology and play a crucial role in their survival and success in their natural habitats.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 382, 'prompt_tokens': 43, 'total_tokens': 425, 'completion_time': 1.072698481, 'prompt_time': 0.001202323, 'queue_time': 0.047548038, 'total_time': 1.073900804}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b8326-2b11-7680-8631-dd3807a24c3a-0', usage_metadata={'input_tokens': 43, 'output_tokens': 382, 'total_tokens': 425}),
#  AIMessage(content="Airplanes fly by using a combination of four main forces: lift, weight, thrust, and drag. Here's a simplified explanation of how these forces work together to keep an airplane in the air:\n\n1. **Lift**: Lift is the upward force that opposes the weight of the airplane and keeps it flying. It's created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the airplane moves forward, the air flows over and under the curved surface of the wing, creating a region of lower pressure above the wing and a region of higher pressure below it. This pressure difference creates an upward force, or lift, that counteracts the weight of the airplane.\n2. **Weight**: Weight is the downward force that pulls the airplane towards the ground. It's the combined weight of the airplane itself, the passengers, cargo, and fuel.\n3. **Thrust**: Thrust is the forward force that propels the airplane through the air. It's created by the airplane's engines, which produce a stream of high-speed air that exits the back of the plane. As this air exits, it produces a forward force that counteracts the drag, or resistance, created by the air.\n4. **Drag**: Drag is the backward force that opposes the motion of the airplane. It's created by the air resistance that the airplane encounters as it moves forward. Drag is affected by the shape of the airplane, its speed, and the density of the air.\n\nTo generate lift, airplanes use a combination of the following:\n\n* **Wing shape**: The curved upper surface of the wing deflects the air downward, creating a region of lower pressure above the wing.\n* **Angle of attack**: The wing is angled slightly upward, which creates a swirling motion behind the wing that helps to increase lift.\n* **Airfoil shape**: The wing is shaped like an airfoil, which is a curved surface that produces lift when air flows over it.\n\nAs the airplane moves forward, the air flows over and under the wing, creating lift. The shape of the wing and the angle of attack work together to produce the optimal amount of lift.\n\nHere's a step-by-step explanation of the process:\n\n1. The airplane's engines produce thrust, propelling the plane forward.\n2. As the plane moves forward, the air flows over and under the wing.\n3. The curved upper surface of the wing deflects the air downward, creating a region of lower pressure above the wing.\n4. The pressure difference between the upper and lower surfaces of the wing creates an upward force, or lift.\n5. The lift counteracts the weight of the airplane, keeping it flying.\n6. The thrust produced by the engines counteracts the drag, or resistance, created by the air.\n7. The airplane continues to fly as long as the lift equals the weight and the thrust equals the drag.\n\nIn summary, airplanes fly by using the shape of the wings to produce lift, and the engines to produce thrust. The four forces of lift, weight, thrust, and drag work together to keep the airplane in the air, allowing it to fly safely and efficiently.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 644, 'prompt_tokens': 40, 'total_tokens': 684, 'completion_time': 1.295505267, 'prompt_time': 0.000968547, 'queue_time': 0.04933843, 'total_time': 1.296473814}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b8326-2b13-76f0-a7f3-953553e11a68-0', usage_metadata={'input_tokens': 40, 'output_tokens': 644, 'total_tokens': 684}),
#  AIMessage(content="Quantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It's a new paradigm for computing that's different from classical computing, which is the type of computing we're familiar with today.\n\n**Classical vs. Quantum Computing**\n\nClassical computers use bits to store and process information. Bits are either 0 or 1, and they're used to perform calculations using logical operations. However, as the number of bits increases, the amount of information that needs to be processed grows exponentially, making it difficult for classical computers to solve complex problems.\n\nQuantum computers, on the other hand, use quantum bits or qubits. Qubits are unique because they can exist in multiple states simultaneously, known as superposition. This means that a qubit can be both 0 and 1 at the same time, allowing for much faster processing of complex calculations.\n\n**Key Principles of Quantum Computing**\n\n1. **Superposition**: Qubits can exist in multiple states (0, 1, or both) simultaneously.\n2. **Entanglement**: Qubits can be connected in such a way that the state of one qubit affects the state of the other, even if they're separated by large distances.\n3. **Quantum parallelism**: Quantum computers can perform many calculations simultaneously, thanks to the principles of superposition and entanglement.\n\n**How Quantum Computing Works**\n\nA quantum computer consists of several components:\n\n1. **Qubits**: The basic units of quantum information, which can exist in multiple states simultaneously.\n2. **Quantum gates**: The quantum equivalent of logic gates in classical computing. Quantum gates perform operations on qubits, such as rotations, entanglement, and measurements.\n3. **Quantum circuits**: A sequence of quantum gates that are applied to qubits to perform a specific calculation.\n4. **Quantum algorithms**: Specialized algorithms designed to take advantage of quantum parallelism and solve complex problems efficiently.\n\n**Applications of Quantum Computing**\n\nQuantum computing has the potential to revolutionize many fields, including:\n\n1. **Cryptography**: Quantum computers can break certain classical encryption algorithms, but they can also be used to create unbreakable quantum encryption methods.\n2. **Optimization**: Quantum computers can be used to solve complex optimization problems, such as finding the shortest path in a network or optimizing complex systems.\n3. **Simulation**: Quantum computers can simulate complex quantum systems, which could lead to breakthroughs in fields like chemistry and materials science.\n4. **Machine learning**: Quantum computers can be used to speed up certain machine learning algorithms, leading to advancements in areas like image recognition and natural language processing.\n\n**Challenges and Limitations**\n\nWhile quantum computing has the potential to solve complex problems efficiently, it's still a developing field with many challenges and limitations. Some of the current limitations include:\n\n1. **Error correction**: Quantum computers are prone to errors due to the fragile nature of qubits.\n2. **Scalability**: Currently, quantum computers are small-scale and need to be scaled up to perform complex calculations.\n3. **Noise and interference**: Quantum computers are sensitive to noise and interference, which can cause errors and instability.\n\nIn summary, quantum computing is a new paradigm for computing that uses the principles of quantum mechanics to perform calculations and operations on data. While it has the potential to revolutionize many fields, it's still a developing field with many challenges and limitations that need to be addressed.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 700, 'prompt_tokens': 40, 'total_tokens': 740, 'completion_time': 1.453256275, 'prompt_time': 0.000948407, 'queue_time': 0.047104351, 'total_time': 1.4 ...
